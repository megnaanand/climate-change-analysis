# %% [markdown]
# <a href="https://colab.research.google.com/github/megnaanand/climate-change-analysis/blob/main/climate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## 1. Introduction
#
# This data exploration and inference project aims to uncover correlations between environmental changes and a global rise in temperatures over the years 1880 to 2020, utilizing datasets provided by NASA Climate Change.

# %% [markdown]
# ### 1.1. Project Overview
# Briefly describe the project's goals and significance.

# %% [markdown]
# ### 1.2. Scope of the Project
# Define the specific aspects of climate change being studied.

# %% [markdown]
# ### 1.3. Data Sources
# Introduce NASA datasets being used (CO2 and Methane levels, Global Temperature, etc.).

# %% [markdown]
# ### 1.4. Importance of the Study
# Discuss the relevance of understanding climate change indicators.

# %% [markdown]
# ## 2. Data Collection and Preprocessing
#  We will be using  information about global Carbon Dioxide and Methane levels, Global Temperature, Ocean Warming, Ice Sheets Sea Levels, and Arctic Sea Ice levels.

# %% [markdown]
# ### 2.1. Data Collection
# Load the datasets from NASA

# %%
df_ice_sheets = pd.read_csv("data/ice_sheets.txt", delim_whitespace=True)
df_ice_sheets['TIME(year.decimal)'] = df_ice_sheets['TIME(year.decimal)'].astype(int)
df_ice_sheets = df_ice_sheets.groupby('TIME(year.decimal)').mean().reset_index()
df_ice_sheets = df_ice_sheets.rename(columns={'TIME(year.decimal)': 'Year'})
print(df_ice_sheets)
# Out:
#     Year  Antarctic-mass(Gigatonnes)  \
# 0   2002                   -7.431429
# 1   2003                 -114.470000
# 2   2004                 -260.975000
# 3   2005                 -227.801667
# 4   2006                 -129.412500
# 5   2007                 -315.981667
# 6   2008                 -586.281667
# 7   2009                 -562.995833
# 8   2010                 -841.445833
# 9   2011                 -940.604444
# 10  2012                -1075.557273
# 11  2013                -1286.856667
# 12  2014                -1498.881111
# 13  2015                -1850.552222
# 14  2016                -1775.763333
# 15  2017                -1818.544000
# 16  2018                -2129.990000
# 17  2019                -2326.797500
# 18  2020                -2557.049167
# 19  2021                -2638.302500
# 20  2022                -2438.013333
# 21  2023                -2329.820000
#
#     Antarctic-mass-1-sigma-uncertainty(Gigatonnes)
# 0                                        91.620000
# 1                                        44.167273
# 2                                        37.161667
# 3                                        34.594167
# 4                                        36.380000
# 5                                        38.661667
# 6                                        40.555000
# 7                                        36.072500
# 8                                        35.743333
# 9                                        40.820000
# 10                                       39.519091
# 11                                       38.198889
# 12                                       33.766667
# 13                                       37.300000
# 14                                       41.070000
# 15                                       60.672000
# 16                                       30.290000
# 17                                       26.829167
# 18                                       26.781667
# 19                                       26.724167
# 20                                       28.221667
# 21                                       45.351667

# %%
df_c02_levels = pd.read_csv("data/c02_levels.txt", delim_whitespace=True)
df_c02_levels = df_c02_levels.groupby('date').mean().reset_index()
df_c02_levels = df_c02_levels.rename(columns={'date': 'Year'})
print(df_c02_levels)
# Out:
#     Year  month  decimal-date  monthly-avg  de-season-alized       days  \
# 0   1958    7.5   1958.580000   315.232000        315.292000  -1.000000
# 1   1959    6.5   1959.497258   315.980833        315.977500  -1.000000
# 2   1960    6.5   1960.498192   316.910000        316.907500  -1.000000
# 3   1961    6.5   1961.497258   317.644167        317.640833  -1.000000
# 4   1962    6.5   1962.497258   318.454167        318.448333  -1.000000
# ..   ...    ...           ...          ...               ...        ...
# 61  2019    6.5   2019.500000   411.649167        411.650000  27.666667
# 62  2020    6.5   2020.500000   414.210833        414.210833  28.000000
# 63  2021    6.5   2021.500000   416.413333        416.414167  28.000000
# 64  2022    6.5   2022.500000   418.528333        418.527500  27.916667
# 65  2023    5.5   2023.416670   421.064000        420.783000  25.900000
#
#     st-dev-days  unc-of-mon-mean
# 0     -9.990000        -0.990000
# 1     -9.990000        -0.990000
# 2     -9.990000        -0.990000
# 3     -9.990000        -0.990000
# 4     -9.990000        -0.990000
# ..          ...              ...
# 61     0.630833         0.230833
# 62     0.508333         0.185000
# 63     0.659167         0.240000
# 64     0.586667         0.212500
# 65     0.540000         0.203000
#
# [66 rows x 8 columns]

# %%
df_global_temperatures = pd.read_csv("data/global_temperatures.txt", delim_whitespace=True)
print(df_global_temperatures)
# Out:
#      Year  No_Smoothing  Lowess(5)
# 0    1880         -0.17      -0.10
# 1    1881         -0.09      -0.13
# 2    1882         -0.11      -0.17
# 3    1883         -0.18      -0.21
# 4    1884         -0.29      -0.24
# ..    ...           ...        ...
# 138  2018          0.85       0.93
# 139  2019          0.97       0.92
# 140  2020          1.01       0.91
# 141  2021          0.84       0.91
# 142  2022          0.89       0.90
#
# [143 rows x 3 columns]

# %%
df_methane = pd.read_csv("data/methane.txt", delim_whitespace=True)
df_methane = df_methane.rename(columns={'year': 'Year'})
print(df_methane)
# Out:
#     Year     mean   unc
# 0   1984  1644.85  0.67
# 1   1985  1657.29  0.59
# 2   1986  1670.09  0.74
# 3   1987  1682.70  0.49
# 4   1988  1693.16  0.67
# 5   1989  1704.53  0.55
# 6   1990  1714.43  0.68
# 7   1991  1724.82  0.72
# 8   1992  1735.47  0.57
# 9   1993  1736.50  0.46
# 10  1994  1742.07  0.58
# 11  1995  1748.88  0.48
# 12  1996  1751.28  0.68
# 13  1997  1754.53  0.42
# 14  1998  1765.54  0.64
# 15  1999  1772.34  0.64
# 16  2000  1773.33  0.81
# 17  2001  1771.22  0.59
# 18  2002  1772.66  0.55
# 19  2003  1777.33  0.50
# 20  2004  1777.05  0.50
# 21  2005  1774.16  0.64
# 22  2006  1774.95  0.56
# 23  2007  1781.37  0.63
# 24  2008  1787.01  0.77
# 25  2009  1793.53  0.69
# 26  2010  1798.93  0.73
# 27  2011  1803.14  0.63
# 28  2012  1808.12  0.63
# 29  2013  1813.41  0.66
# 30  2014  1822.57  0.53
# 31  2015  1834.26  0.55
# 32  2016  1843.12  0.68
# 33  2017  1849.58  0.64
# 34  2018  1857.33  0.82
# 35  2019  1866.58  0.60
# 36  2020  1878.93  0.56
# 37  2021  1895.28  0.55
# 38  2022  1911.82  0.78

# %%
df_sea_levels = pd.read_csv("data/sea_levels.txt", delim_whitespace=True)
df_sea_levels['year_fraction_of_year'] = df_sea_levels['year_fraction_of_year'].astype(int)
df_sea_levels = df_sea_levels.groupby('year_fraction_of_year').mean().reset_index()
df_sea_levels = df_sea_levels.rename(columns={'year_fraction_of_year': 'Year'})
print(df_sea_levels)
# Out:
#     Year  altimeter_type  merged_file_cycle_#  number_of_observations  \
# 0   1993           81.00            29.000000           438921.432432
# 1   1994           81.00            66.000000           445283.621622
# 15                          86.268333          3.503611e+00     7.331944
# 16                          84.531622          8.367568e+00    12.434865
# 17                          86.690541          9.426486e+00    13.661622
# 18                          87.350811          8.530541e+00    12.944595
# 19                          84.558378          1.917892e+01    24.011622
# 20                          84.447838          2.135324e+01    26.309189
# 21                          84.503889          2.477250e+01    30.091111
# 22                          94.597838          3.551351e+01    40.910541
# 23                          90.919459          3.743622e+01    43.196486
# 24                          84.585405          3.833514e+01    44.297568
# 25                          86.053243          4.231973e+01    48.465946
# 26                          87.808649          4.906405e+01    55.612162
# 27                          87.150556          4.984528e+01    56.413333
# 28                          87.137297          5.392595e+01    60.873514
# 29                          88.444324          5.620054e+01    63.486216
# 30                          86.311500          5.710400e+01    64.598000
#
#     standard_deviation_GMSL_GIA_mm  smoothed_GMSL_GIA_mm  \
# 0                        87.612432            -34.528108
# 1                        87.432162            -30.552432
# 2                        85.357297            -27.376486
# 3                        84.221944            -25.305556
# 4                        98.040541            -21.270811
# 5                        96.184324            -23.648378
# 6                        86.704054            -20.036216
# 7                        85.911081            -16.787297
# 8                        83.949189            -11.213784
# 9                        85.449444             -7.076667
# 10                       86.612703             -3.708919
# 11                       85.564865             -1.749189
# 12                       84.549730              3.044595
# 13                       85.337222              4.396944
# 14                       84.635135              5.103514
# 15                       86.246111              7.282778
# 16                       84.568378             12.387297
# 17                       86.701351             13.690811
# 18                       87.350811             13.036757
# 19                       84.598378             23.925405
# 20                       84.470000             26.346486
# 21                       84.702500             30.000833
# 22                       94.895135             40.987297
# 23                       91.112703             43.153243
# 24                       84.826486             44.298919
# 25                       86.218378             48.524865
# 26                       88.024054             55.510270
# 27                       87.258611             56.546667
# 28                       87.179189             60.865135
# 29                       88.608108             63.385405
# 30                       86.308500             64.477000
#
#     smoothed_GMSL_GIA_annual_semi_removed_mm  \
# 0                                 -34.528108
# 1                                 -30.551892
# 2                                 -27.375405
# 3                                 -25.304722
# 4                                 -21.271622
# 5                                 -23.648649
# 6                                 -20.035946
# 7                                 -16.786757
# 8                                 -11.212432
# 9                                  -7.076111
# 10                                 -3.710270
# 11                                 -1.749189
# 12                                  3.044054
# 13                                  4.507778
# 14                                  5.104595
# 15                                  7.283056
# 16                                 12.386486
# 17                                 13.690000
# 18                                 13.037297
# 19                                 23.925946
# 20                                 26.346757
# 21                                 30.001389
# 22                                 40.986757
# 23                                 43.153243
# 24                                 44.298649
# 25                                 48.525405
# 26                                 55.511351
# 27                                 56.547778
# 28                                 60.864595
# 29                                 63.384324
# 30                                 66.915000
#
#     smoothed_GMSL_no_GIA_annual_semi_removed_mm
# 0                                    -34.649459
# 1                                    -30.918108
# 2                                    -27.986216
# 3                                    -26.157222
# 4                                    -22.363514
# 5                                    -24.982162
# 6                                    -21.618919
# 7                                    -18.614054
# 8                                    -13.287838
# 9                                     -9.390278
# 10                                    -6.265135
# 11                                    -4.551081
# 12                                     0.000000
# 13                                     1.227222
# 14                                     1.568919
# 15                                     3.504444
# 16                                     8.366216
# 17                                     9.426486
# 18                                     8.529730
# 19                                    19.178108
# 20                                    21.353784
# 21                                    24.772778
# 22                                    35.512703
# 23                                    37.435946
# 24                                    38.335135
# 25                                    42.319730
# 2010      4.865    6.984     9.614    11.831  10.711
# 2011      4.561    6.465     9.772    12.154  10.483
# 2012      3.566    5.886     9.388    12.006  10.406
# 2013      5.208    7.455     9.939    12.184  10.897
# 2014      5.220    7.232    10.115    12.353  10.790
# 2015      4.616    6.966     9.846    12.045  10.566
# 2016      4.528    6.082     8.658    11.459  10.163
# 2017      4.822    6.767     9.493    11.743  10.393
# 2018      4.785    6.134     9.823    11.862  10.355
# 2019      4.364    5.735     9.353    11.903  10.201
# 2020      4.001    5.334     8.985    11.729  10.150
# 2021      4.952    6.816     9.830    12.152  10.552
# 2022      4.897    6.657     9.725    11.892  10.661
# 2023      4.371    6.367       NaN       NaN  10.393

# %%
merged_df = pd.merge(df_ice_sheets, df_global_temperatures, on='Year', how='outer')
merged_df = pd.merge(merged_df, df_methane, on='Year', how='outer')
merged_df = pd.merge(merged_df, df_sea_levels, on='Year', how='outer')
merged_df = pd.merge(merged_df, df_ocean_warming, on='Year', how='outer')
merged_df = pd.merge(merged_df, df_arctic_sea_ice, on='Year', how='outer')
merged_df = merged_df.sort_values(by='Year')
print(merged_df)
# Out:
#     Year  Antarctic-mass(Gigatonnes)  \
# 22  1880                         NaN
# 23  1881                         NaN
# 24  1882                         NaN
# 25  1883                         NaN
# 26  1884                         NaN
# ..   ...                         ...
# 17  2019                -2326.797500
# 18  2020                -2557.049167
# 19  2021                -2638.302500
# 20  2022                -2438.013333
# 21  2023                -2329.820000
#
#     Antarctic-mass-1-sigma-uncertainty(Gigatonnes)  No_Smoothing  Lowess(5)  \
# 22                                             NaN         -0.17      -0.10
# 23                                             NaN         -0.09      -0.13
# 24                                             NaN         -0.11      -0.17
# 25                                             NaN         -0.18      -0.21
# 26                                             NaN         -0.29      -0.24
# ..                                             ...           ...        ...
# 17                                       26.829167          0.97       0.92
# 18                                       26.781667          1.01       0.91
# 19                                       26.724167          0.84       0.91
# 20                                       28.221667          0.89       0.90
# 21                                       45.351667           NaN        NaN
#
#        mean   unc  altimeter_type  merged_file_cycle_#  \
# 22      NaN   NaN             NaN                  NaN
# 23      NaN   NaN             NaN                  NaN
# 24      NaN   NaN             NaN                  NaN
# 25      NaN   NaN             NaN                  NaN
# 26      NaN   NaN             NaN                  NaN
# ..      ...   ...             ...                  ...
# 17  1866.58  0.60             0.0                987.0
# 18  1878.93  0.56             0.0               1023.5
# 19  1895.28  0.55             0.0               1060.0
# 20  1911.82  0.78             0.0               1097.0
# 21      NaN   NaN             0.0               1125.5
#
#     number_of_observations  ...   April     May    June   July  August  \
# 22                     NaN  ...     NaN     NaN     NaN    NaN     NaN
# 23                     NaN  ...     NaN     NaN     NaN    NaN     NaN
# 24                     NaN  ...     NaN     NaN     NaN    NaN     NaN
# 25                     NaN  ...     NaN     NaN     NaN    NaN     NaN
# 26                     NaN  ...     NaN     NaN     NaN    NaN     NaN
# ..                     ...  ...     ...     ...     ...    ...     ...
# 17           439841.027027  ...  13.434  12.186  10.594  7.589   5.026
# 18           436136.638889  ...  13.621  12.343  10.593  7.294   5.070
# 19           459071.756757  ...  13.792  12.682  10.765  7.647   5.715
# 20           459525.621622  ...  13.986  12.879  10.875  8.287   5.950
# 21           464334.050000  ...  13.992  12.835  10.963  8.183   5.566
#
#     September  October  November  December  Annual
# 22        NaN      NaN       NaN       NaN     NaN
# 23        NaN      NaN       NaN       NaN     NaN
# 24        NaN      NaN       NaN       NaN     NaN
# 25        NaN      NaN       NaN       NaN     NaN
# 26        NaN      NaN       NaN       NaN     NaN
# ..        ...      ...       ...       ...     ...
# 17      4.364    5.735     9.353    11.903  10.201
# 18      4.001    5.334     8.985    11.729  10.150
# 19      4.952    6.816     9.830    12.152  10.552
# 20      4.897    6.657     9.725    11.892  10.661
# 21      4.371    6.367       NaN       NaN  10.393
#
# [144 rows x 33 columns]

# %% [markdown]
# ### 2.2. Data Preprocessing

# %% [markdown]
# #### 2.2.1. Data Cleaning
# Handle missing values, outliers, and other inconsistencies

# %% [markdown]
# #### 2.2.2. Data Transformation
# Normalize, scale, or transform data as needed for analysis.

# %% [markdown]
# #### 2.2.3. Data Integration
# Combine different datasets into a cohesive format.

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 3.1. Initial Data Exploration
# Use basic statistics and visualizations to understand the datasets.

# %% [markdown]
# ### 3.2. Correlation Analysis

# %% [markdown]
# #### 3.2.1. Heatmaps
# Visualize correlations between different environmental indicators.

# %% [markdown]
# #### 3.2.2. Geographic Heatmaps
# Show spatial distribution of climate change indicators.

# %% [markdown]
# ### 3.3. Time Series Analysis

# %% [markdown]
# #### 3.3.1. Line Plots
# Examine trends in temperature and other variables over time.

# %% [markdown]
# #### 3.3.2. Seasonal Analysis
# Investigate seasonal patterns in the data.

# %% [markdown]
# ## 4. Data Visualization and Inference

# %% [markdown]
# ### 4.1. Advanced Data Visualization

# %% [markdown]
# #### 4.1.1. Interactive Plots
# Create dynamic plots for more engaging data exploration.

# %% [markdown]
# #### 4.1.2. Comparative Visualizations
# Compare different indicators side-by-side

# %% [markdown]
# ### 4.2. Inference from Visualizations
# Draw conclusions from the visualizations created.

# %% [markdown]
# ## 5. Predictive Modeling

# %% [markdown]
# ### 5.1. Model Selection
# Discuss the selection of predictive models

# %% [markdown]
# ### 5.2. Model Training and Validation
# Train models on historical data and validate their performance.

# %% [markdown]
# ### 5.3. Forecasting
# Use the models to forecast future climate trends based on historical data.

# %% [markdown]
# ## 6. Discussion and Insights

# %% [markdown]
# ### 6.1. Key Findings
# Summarize the major insights gained from the analysis.

# %% [markdown]
# ### 6.2. Unexpected Discoveries
# Highlight any surprising patterns or results.

# %% [markdown]
# ### 6.3. Limitations of the Study
# Acknowledge any limitations in data or methodology.

# %% [markdown]
# ## 7. Conclusion and Future Implications

# %% [markdown]
# ### 7.1. Implications of Findings
# Discuss how your findings impact our understanding of climate change.

# %% [markdown]
# ### 7.2. Recommendations for Future Research
# Suggest areas for further investigation.

# %% [markdown]
# ### 7.3. Final Thoughts
# Restate the importance of the project and its contributions to the field.

# %% [markdown]
# ## 8. References

# %% [markdown]
# ### 8.1. Data Sources
# Cite the NASA datasets and any other sources used.

# %% [markdown]
# ### 8.2. Additional Literature
# Reference any additional literature that supported your analysis

# %% [markdown]
# ## 9. Appendix

# %% [markdown]
# ### 9.1. Additional Data
# Include any supplementary data or analysis.

# %% [markdown]
# ### 9.2. Code Documentation
# Provide detailed comments and documentation for the code used.
